# %% [markdown]
# <a href="https://colab.research.google.com/github/lkaucz/Mecatronics---Projects/blob/main/4_Data_visualization_ing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Data visualization
#
# We will use Python's matplotlib library, along with numpy and pandas functions, to visualize numerical and categorical data. These plots will later be used for data analysis.
#
# Another library, called seaborn, can also be used for plotting graphs. It will be mentioned in some charts, but it is not the focus of this lesson. Feel free to search and improve! Plotly

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Just as a first iteration, let's plot a sine with frequency 1/2pi:

# %%
t = np.arange(0,2*np.pi,0.1)
y = np.sin(t)
plt.plot(t,y)

# %% [markdown]
# A 2D graphic plot will always need 2 arrays, one for x (horizontal axis) and one for y (vertical axis). 3D plots also exist, being used to visualize temporal variations (where t is the 3rd axis), to visualize surfaces and to visualize the correlation between three variables. We will deal with the 3D plot at the end of the class.
#
# https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
#
# Create any function you desire and plot it in a line graph:

# %%
#try here

# %% [markdown]
# Continuing with the line graphs (very used in engineering), let's see how to plot pre-existing arrays, without using a function, and change your plot settings:

# %%
Years = []
for i in range(1965,2020):
    Years.append(i)
Use_BR = [26.319, 26.386, 26.641, 24.385, 23.901, 25.423, 25.274, 25.726, 24.618,
       25.542, 26.609, 27.747, 29.318, 29.268, 30.743, 33.278, 34.638, 35.656, 
       37.685, 38.505, 38.72, 37.149, 36.762, 37.893, 38.184, 43.859, 44.44,
       43.476, 43.727, 43.138, 42.923, 42.655, 42.06, 42.135, 41.706, 41.859,
       37.819, 39.48, 40.939, 40.915, 41.76, 41.636, 42.989, 42.015, 44.945, 
       42.868, 42.45, 40.629, 38.35, 37.398, 38.632, 41.467, 41.15, 43.79, 
       45.017]

Use_EUA = [4.049, 3.864, 4.21, 4.008, 4.251, 4.073, 4.273, 4.185, 4.031, 4.544,
           4.633, 4.21, 3.275, 4.066, 4.027, 4.138, 4.059, 4.929, 5.335, 4.993,
           4.459, 4.598, 3.95, 3.431, 4.034, 4.436, 4.435, 3.995, 4.289, 3.99,
           4.472, 4.711, 4.805, 4.41, 4.304, 3.78, 3.203, 3.761, 3.921, 3.85,
           3.962, 4.408, 4.128, 4.75, 5.515, 5.562, 6.559, 6.541, 6.746, 6.859,
           7.047, 7.82, 8.568, 8.467, 8.712]

print(plt.style.available)
Years
Use_BR
Use_EUA
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# [4.049,
#  3.864,
#  4.21,
#  4.008,
#  4.251,
#  4.073,
#  4.273,
#  4.185,
#  4.031,
#  4.544,
#  4.633,
#  4.21,
#  3.275,
#  4.066,
#  4.027,
#  4.138,
#  4.059,
#  4.929,
#  5.335,
#  4.993,
#  4.459,
#  4.598,
#  3.95,
#  3.431,
#  4.034,
#  4.436,
#  4.435,
#  3.995,
#  4.289,
#  3.99,
#  4.472,
#  4.711,
#  4.805,
#  4.41,
#  4.304,
#  3.78,
#  3.203,
#  3.761,
#  3.921,
#  3.85,
#  3.962,
#  4.408,
#  4.128,
#  4.75,
#  5.515,
#  5.562,
#  6.559,
#  6.541,
#  6.746,
#  6.859,
#  7.047,
#  7.82,
#  8.568,
#  8.467,
#  8.712]

# %%
plt.plot(Years,Use_BR,label='Brazil',linestyle='-',color='m',marker='',
         linewidth=2)


#plt.show() # when used in terminal (as in the software "spider" - opens a window)

# %% [markdown]
# #Now plot Use_EUA, with a linestyle --:

# %%
#try here

# %%
plt.plot(Years,Use_EUA,label='EUA',linestyle='--',color='b',
         marker='',linewidth=1)

# %% [markdown]
# #Let's try to plot both lines in one graph:

# %%
#try here

# %%
plt.plot(Years,Use_BR,label='Brazil',linestyle='-',color='k',marker='',
         linewidth=1)
plt.plot(Years,Use_EUA,label='EUA',linestyle='--',color='b',
         marker='',linewidth=1)

# %% [markdown]
# #Search in the plt API and add: figure title, labels, legend, with a grid. Try also to use a different plt style:

# %%
#try here

# %%
#plt.style.use('dark_background')
plt.style.use('default')
plt.plot(Years,Use_BR,label='Brazil',linestyle='-',color='k',marker='',
         linewidth=1)
plt.plot(Years,Use_EUA,label='EUA',linestyle='--',color='b',
         marker='',linewidth=1)
plt.xlabel(u'Years')
plt.ylabel(u'Use of renewable energy in its energy matrix (%)')
plt.title("Use of renewable energy")
plt.xlim(1965,2019)
plt.ylim(0,50)
plt.legend()
plt.grid(True)
plt.tight_layout() # used online with subplots
plt.savefig('plot1.png')
#plt.show() # when used in terminal (as in the software "spider" - opens a window)

# %% [markdown]
# Change layout settings, colors, line styles in the above chart to test.

# %%
#plt.style.use('dark_background')
plt.style.use('default')
plt.plot(Years,Use_BR,label='Brazil',linestyle=' ',color='k',marker='*',
         linewidth=3)
plt.plot(Years,Use_EUA,label='EUA',linestyle='-',color='b',
         marker='',linewidth=3)
plt.xlabel(u'Years')
plt.ylabel(u'Use of renewable energy in its energy matrix (%)')
plt.title("Use of renewable energy")
plt.xlim(1960,2020)
plt.ylim(0,50)
plt.legend()
plt.grid(True)
#plt.tight_layout() # used online with subplots
plt.savefig('plot1.png')
#plt.show() # when used in terminal (as in the software "spider" - opens a window)

# %% [markdown]
# There are many cases where we need to visualize more than one graph, one next to the other. In this case, we use subplots.

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), color='b', marker='o')
plt.plot(t2, f(t2), color='k')
plt.grid(True)

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), color='orange', linestyle='--')

plt.tight_layout()

# %% [markdown]
# Another important chart for data visualization is the bar chart. In matplotlib, we use the bar() method for this plot.
#
# What types of data would benefit from the bar plot?

# %%
categories = ['A','B','C','D']
values = [10, 20, 15, 5]

# %% [markdown]
# #Look for plt.bar in the plt API and try to plot the bar plot using the lists created in the code line above:

# %%
#try here

# %%
plt.figure(figsize=(9, 3)) # Changes figure size
plt.bar(categories,values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Title')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# The same characteristics that we changed in the line chart can be changed in the bar chart.
#
# Try to plot the "Use_BR" and "Use_EUA" data provided before in a bar plot:

# %%
plt.bar(Years,Use_BR,label='Brazil',color='g')
plt.bar(Years,Use_EUA,label='EUA',color='b')
plt.xlabel(u'Years')
plt.ylabel(u"Percentage of renewable energy use (%)")
plt.title(u'Use of renewable energy')
plt.ylim(0,50)
plt.xlim(1960,2020)
plt.legend()
#plt.tight_layout()
plt.show()

# %% [markdown]
# Another way to read a DataFrame is if it is available online:

# %%
filmes_url = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_url)
type(filmes)
# Out:
# pandas.core.frame.DataFrame

# %%
filmes.head()
# Out:
#                                           Film  Year      Genre  \
# 0  Harry Potter and the Deathly Hallows Part 2  2011    Fantasy
# 1                         Mission Impossible 4  2011     Action
# 2                                  Toy Story 3  2010  Animation
# 3                                         2012  2009     Action
# 4                          Alice in Wonderland  2010  Adventure
#
#    Worldwide_Gross_M  Budget_M
# 0               1328       125
# 1                689       145
# 2               1063       200
# 3                768       200
# 4               1024       200

# %% [markdown]
# #Using your pandas knowleadge and matplotlib, create a bar plot that shows the number of movies in each Genre there in the filmes dataset.

# %%
contagens = filmes.groupby(by='Genre').count()
contagens
# Out:
#            Film  Year  Worldwide_Gross_M  Budget_M
# Genre
# Action       13    13                 13        13
# Adventure     4     4                  4         4
# Animation     8     8                  8         8
# Drama         2     2                  2         2
# Fantasy       1     1                  1         1
# Romance       1     1                  1         1
# Thriller      1     1                  1         1

# %%
plt.figure(figsize=(8, 4)) # change the figure size
plt.bar(contagens.index, contagens['Film'])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# With the seaborn library, we can do things a little more directly:

# %%
plt.figure(figsize=(15,8))
plt.title('Films by genre each year')
sns.countplot(x="Year", hue= 'Genre', data=filmes)

# %%
from google.colab import drive
drive.mount('/content/drive')
#path = '/content/drive/My Drive/Colab_Classes/MachineLearning/Colab_ing/DataFrames/'
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Colab_Classes/MachineLearning/Colab_ing/DataFrames/'
wine_reviews = pd.read_csv(path + 'winemag-data-130k-v2.csv')


display(wine_reviews.head())
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
plt.figure(figsize=(50,8))
sns.countplot(x="country", data=wine_reviews)

# %% [markdown]
# The histogram is essentially a bar graph. However, it has the specificity of counting amounts of quantitative data values in ranges of values. Thus, the histogram allows us to analyze which intervals are more frequent and which are not, giving a good idea of how the values of this attribute are distributed.

# %%
plt.figure(figsize=(10, 5))
plt.title('Wine points distribution')
plt.hist(wine_reviews['points']);

# %% [markdown]
# #Now try and creat an histogram with the wine prices:

# %%
#try here

# %%
plt.figure(figsize=(10, 5))
plt.title('Wine prices distribution')
plt.hist(wine_reviews['price']);

# %% [markdown]
# #Not really interesting, right? Look for the "bins" atribute in the plt.hist API and try to correct it:

# %%
plt.figure(figsize=(10, 5))
plt.title('Wine prices distribution')
plt.hist(wine_reviews['price'],bins=1000);
plt.xlim(0,250)
# Out:
# (0.0, 250.0)

# %%
plt.figure(figsize=(10, 5))
plt.title('Wine prices distribution')
plt.xlim(0,200)
plt.hist(wine_reviews['price'],bins=2000);

# %% [markdown]
# Pie charts can also be used for data visualization. Can you think of a use in engineering?

# %%
failure = ['Normal', 'Failure type 1', 'Failure type 2']
quantidade = [110,90,30]
plt.title('Proportion of bearing failure cases')
plt.pie(x=quantidade, labels = failure);

# %%
plt.figure(figsize=(6,6))
plt.title('Proportion of bearing failure cases')
plt.pie(x=quantidade, labels = failure, autopct='%1.1f%%')
#plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb059619ed0>,
# ...
#  [Text(0.07506663683168746, 1.097435647331897, 'Normal'),
#   Text(-0.506071521625399, -0.9766737505430119, 'Failure type 1'),
#   Text(1.0089324334399592, -0.43824119472377604, 'Failure type 2')],
#  [Text(0.040945438271829525, 0.5986012621810346, '47.8%'),
#   Text(-0.27603901179567214, -0.5327311366598246, '39.1%'),
#   Text(0.5503267818763413, -0.23904065166751415, '13.0%')])

# %%
#plt.pie(x=contagens['Worldwide_Gross_M'], labels = contagens.index, autopct='%1.1f%%',startangle=90);
plt.pie(x=contagens['Worldwide_Gross_M'], labels = contagens.index, autopct='%1.1f%%',startangle=90, pctdistance=0.9);

# %% [markdown]
# Scatter plots give us an idea of ​​the relationship between two variables:

# %%
#plt.figure(figsize=(8,5))
plt.title('Relationship between wine points and wine price')
sns.scatterplot(x="points", y="price", data=wine_reviews)
#sns.scatterplot(x="price", y="points", data=wine_reviews)

# %% [markdown]
# And we can already plot a regression line!

# %%
plt.figure(figsize=(8,5))
plt.title('Relationship between wine points and wine price')
sns.regplot(x="points", y="price", data=wine_reviews)
#sns.regplot(x="price", y="points", data=wine_reviews);

# %% [markdown]
# We can also apply "hues", as done in bar charts, to visualize correlations of more than one variable.
# sns.scatterplot(x="'___'", y="'_____'", hue = '_____', data='_____')

# %% [markdown]
# #Can you create a scatterplot using the a plt graph?

# %%
#try here

# %%
plt.plot(wine_reviews['points'],wine_reviews['price'],linestyle='',color='k',marker='o',
         linewidth=1)

# %%
uri = 'https://raw.githubusercontent.com/cabrau/curso-analise-visualizacao-dados-python/master/room_data.txt'
room = pd.read_csv(uri)
room.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio
# 0  2015-02-04 18:49:59       22.290   27.3900    0.0  621.00       0.004559
# 1  2015-02-04 19:50:00       21.890   27.1000    0.0  548.50       0.004401
# 2  2015-02-04 20:50:00       21.600   26.4725    0.0  509.75       0.004222
# 3  2015-02-04 21:49:59       21.445   25.7450    0.0  488.00       0.004067
# 4  2015-02-04 22:50:00       21.290   25.7000    0.0  467.00       0.004021

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature variation over time')
sns.scatterplot(x="date", y="Temperature", data=room)

# %% [markdown]
# #The visualization is bad, right? Shall we try it on the line graph we already know?

# %%
#try here

# %%
plt.plot(room['date'],room['Temperature'])

# %% [markdown]
# Much better! But the dates are still unintelligible. Let's fix this and take the opportunity to see how we plot a line chart in seaborn:

# %%
room['date'] = pd.to_datetime(room['date'])
plt.figure(figsize=(10,5))
plt.title('Temperature variation over time')
sns.lineplot(x="date", y="Temperature", data=room)

# %% [markdown]
# Before we proceed to the 3D graphics, let's rake a look at the famous boxplot, using matplotlib and seaborn, using the famous Titanic data, a DataFrame that already exists within the seaborn library.

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.title('Passenger age in each class')
plt.boxplot(titanic['age']);

# %%
titanic[titanic['age'].isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ages = titanic[titanic['age'].notna()]['age']
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
plt.title('Passenger age')
plt.boxplot(ages);

# %%
plt.title('Passenger age in each class and sex')
sns.boxplot(x="class", y="age", hue = 'sex', data=titanic);

# %% [markdown]
# Finally, let's see two types of 3D plots using matplotlib (taken from the matplotlib library documentation itself - https://matplotlib.org/2.0.2/mpl_toolkits/mplot3d/tutorial.html).

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
from matplotlib import colors as mcolors


fig = plt.figure()
ax = fig.gca(projection='3d')


def cc(arg):
    return mcolors.to_rgba(arg, alpha=0.6)

xs = np.arange(0, 10, 0.4)
verts = []
zs = [0.0, 1.0, 2.0, 3.0]
for z in zs:
    ys = np.random.rand(len(xs))
    ys[0], ys[-1] = 0, 0
    verts.append(list(zip(xs, ys)))

poly = PolyCollection(verts, facecolors=[cc('r'), cc('g'), cc('b'),
                                         cc('y')])
poly.set_alpha(0.7)
ax.add_collection3d(poly, zs=zs, zdir='y')

ax.set_xlabel('X')
ax.set_xlim3d(0, 10)
ax.set_ylabel('Y')
ax.set_ylim3d(-1, 4)
ax.set_zlabel('Z')
ax.set_zlim3d(0, 1)
# Out:
# (0.0, 1.0)

# %%
'''
=================
3D wireframe plot
=================

A very basic demonstration of a wireframe plot.
'''

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
